# %% [markdown]
# # Reviews of 12 different products (including Beeats Pill product review)

# %%
# Importing numpy and pandas library
import numpy as np
import pandas as pd

# %%
# Reading a csv file from local machine
df = pd.read_csv('merged_reviews_data.csv')

# %%
# display first 10 rows
df.head(10)
# Out:
#         review_id  product_id  \
# 0  R2SSSH04J4J264  B0D4SX9RC6
# 1   R935PCZ92UVGL  B0D4SX9RC6
# 2   R4BQHA0TLLJNN  B0D4SX9RC6
# 3  R39X7USU3OX34C  B0D4SX9RC6
# 4  R2EVRTXO9M1YF7  B0D4SX9RC6
# 5  R1BHCCLK5GZ5VZ  B0D4SX9RC6
# 6  R26LL57PKV8KR5  B0D4SX9RC6
# 7  R3EOM3PFJ90D5Y  B0D4SX9RC6
# 8   RTDXQGCW5S0SA  B0D4SX9RC6
# 9  R10YJBZGOB4SBS  B0D4SX9RC6
#
#                                                title            author  \
# 0  5.0 out of 5 stars Really nice portable speake...           Bruce C
# 1                      5.0 out of 5 stars Very Happy         B. Hinson
# 2  5.0 out of 5 stars The best Speaker I have eve...              Leox
# 3                     5.0 out of 5 stars Really good            Justin
# 4           4.0 out of 5 stars Is it the JBL killer?             Tommy
# 5                      5.0 out of 5 stars Beats Pill  Gregory Stratman
# 6                      5.0 out of 5 stars Beats pill            Jewels
# 7  3.0 out of 5 stars Good design, but bass disto...            Daniel
# 8                  4.0 out of 5 stars Almost perfect           Scooley
# 9  4.0 out of 5 stars No App for IOS. No way to d...  Kindle in Hawaii
#
#    rating                                            content  \
# 0       5  Needed a new portable speaker for the home set...
# 1       5  We bought this for a trip to the beach and it ...
# 2       5  I really like the new Beats Pill 2024 speaker....
# 3       5  So I’m super picky about sound and have spent ...
# 4       4  I bought this because it was on sale, and I al...
# 5       5  I love the size, weight and quality of my Pill...
# 6       5  The sound on this is like having a stereo with...
# 7       3  The new pill looks awesome, and built extremel...
# 8       4  I bought the new pill mainly to use wired for ...
# 9       4  Love these speakers, but Apple seemed to have ...
#
#                                          timestamp  \
# 0       Reviewed in the United States July 1, 2024
# 1  Reviewed in the United States September 5, 2024
# 2      Reviewed in the United States July 11, 2024
# 3       Reviewed in the United States July 8, 2024
# 4      Reviewed in the United States July 23, 2024
# 5     Reviewed in the United States August 2, 2024
# 6  Reviewed in the United States September 1, 2024
# 7       Reviewed in the United States July 2, 2024
# 8    Reviewed in the United States August 13, 2024
# 9    Reviewed in the United States August 15, 2024
#
#                      profile_id  is_verified  helpful_count  \
# 0  AFVM53KRAU5JC462ZZDBBKTESPGA         True             18
# 1  AFPN35SDBWBDQAGNSNQJQPQH5C2Q         True              0
# 2  AEUCX7EIPTMCFN4OJBZHL2OYSVKQ         True              8
# 3  AFSZPNTTLYCLNP536L6VS6UMFTNQ         True              7
# 4  AHAMVBSECCNUJMQV6A3BO3A3HNMA         True              5
# 5  AHCXUEC2FLLJ3S6F762OSBZJRDPA         True              5
# 6  AEHRQAFGWSQYA4HOPI62OVHCFDZQ         True              0
# 7  AHAIN2MT2BFGIAXCVJCMTI6NEDGA         True              6
# 8  AHRRPRN7Y4X3UP2Z3YN6EWQJCUVQ         True              3
# 9  AEF7JE6TACESBPXTYHKCLUEIJVFA         True              0
#
#                                   product_attributes
# 0  Color: Statement RedStyle: PillPattern: Withou...
# 1  Color: Champagne GoldStyle: PillPattern: Witho...
# 2  Color: Champagne GoldStyle: PillPattern: Witho...
# 3  Color: Statement RedStyle: PillPattern: Withou...
# 4  Color: Matte BlackStyle: PillPattern: Without ...
# 5  Color: Matte BlackStyle: PillPattern: Without ...
# 6  Color: Matte BlackStyle: PillPattern: Without ...
# 7  Color: Matte BlackStyle: PillPattern: Without ...
# 8  Color: Matte BlackStyle: PillPattern: Without ...
# 9  Color: Champagne GoldStyle: PillPattern: Witho...

# %%
# Viewing all different columns
df.columns
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')

# %%
# viewing different types
df.dtypes
# Out:
# review_id             object
# product_id            object
# title                 object
# author                object
# rating                 int64
# content               object
# timestamp             object
# profile_id            object
# is_verified             bool
# helpful_count          int64
# product_attributes    object
# dtype: object

# %% [markdown]
# # Identifying Outliers

# %%
# Summary statistics
df.describe()
# Out:
#             rating  helpful_count
# count  1080.000000    1080.000000
# mean      4.522222       3.858333
# std       0.891452      17.927444
# min       1.000000       0.000000
# 25%       4.000000       0.000000
# 50%       5.000000       0.000000
# 75%       5.000000       2.000000
# max       5.000000     284.000000

# %%
# Summary statistics for columns with object types
df.describe(include='object')
# Out:
#              review_id  product_id                           title  \
# count             1080        1080                            1080
# unique            1080          12                             985
# top     R215G1OC4IVNBL  B0BSNZJGTX  5.0 out of 5 stars Great sound
# freq                 1         100                              11
#
#                  author    content  \
# count              1080       1080
# unique              993       1075
# top     Amazon Customer  Excelente
# freq                 47          3
#
#                                             timestamp  \
# count                                            1080
# unique                                            533
# top     Reviewed in the United States August 15, 2024
# freq                                               10
#
#                           profile_id product_attributes
# count                           1080                980
# unique                          1078                 36
# top     AHFQM5SAW3MYYQ4D6L7RUL6RMFNQ       Color: Black
# freq                               2                210

# %%
# Shape of the dataframe
df.shape
# Out:
# (1080, 11)

# %% [markdown]
# # Cleaning Data process
#
# 1. Identifying null values and replacing it with accurate values

# %%
# calculating rows with null using isnull() method
df.isnull().sum()
# Out:
# review_id               0
# product_id              0
# title                   0
# author                  0
# rating                  0
# content                 0
# timestamp               0
# profile_id              0
# is_verified             0
# helpful_count           0
# product_attributes    100
# dtype: int64

# %%
# calculating rows with null using isnull() method in product_attribute column
df[df['product_attributes'].isnull()]
# Out:
#           review_id  product_id  \
# 880   RI4J0OA8QEHX8  B09PMYTJD2
# 881    REPT12N1Z65B  B09PMYTJD2
# 882  R2D4M42M5NELUB  B09PMYTJD2
# 883   RZN1X5HHIPU79  B09PMYTJD2
# 884   RWUVNJD6SC9JC  B09PMYTJD2
# ..              ...         ...
# 975   R1ETA2URW8F7Z  B09PMYTJD2
# 976  R327YT3BDZYU7P  B09PMYTJD2
# 977  R1XWYTWY3KZHT4  B09PMYTJD2
# 978  R1VG7FOEEHQUJJ  B09PMYTJD2
# 979   RQAC8XTGY3I9T  B09PMYTJD2
#
#                                                  title              author  \
# 880       5.0 out of 5 stars Simply top of its class!!      Dr. Ace Farley
# 881           5.0 out of 5 stars Tribit Stormbox Blast                BLRG
# 882                   5.0 out of 5 stars Awesome Sound  Ryan Nobles-Fisher
# 883  5.0 out of 5 stars Unbeatable price/performanc...             Corndog
# 884           4.0 out of 5 stars Great initial quality      SuperBlindGirl
# ..                                                 ...                 ...
# 975                    5.0 out of 5 stars Good Product                 Leo
# 976    3.0 out of 5 stars Decent product for basic use           Boxranger
# 977            5.0 out of 5 stars Exceptionally good 🔊                   T
# 978                               5.0 out of 5 stars 🫠     SumtingSumwhere
# 979                        4.0 out of 5 stars 4/5 star            unlisted
#
#      rating                                            content  \
# 880       5  This Stormbox blast is simply the benchmark in...
# 881       5  Arrived yesterday and connected it straight aw...
# 882       5  Was considering this or the JBL equivalent, bu...
# 883       5  Sure, it's a bit weighty, but I'd rather that ...
# 884       4  Writing this review from one blind person's pe...
# ..      ...                                                ...
# 975       5                                   Very good sound.
# 976       3  I liked the weight and construction of the uni...
# 977       5  This speaker is absolutely perfect. It sounds ...
# 978       5  The media could not be loaded. OMFG.Listen, yo...
# 979       4  Great sound would be 5/5 but controls are limi...
#
#                                            timestamp  \
# 880    Reviewed in the United States August 27, 2024
# 881  Reviewed in the United States September 1, 2023
# 882    Reviewed in the United States August 15, 2024
# 883    Reviewed in the United States January 9, 2023
# 884    Reviewed in the United States August 27, 2024
# ..                                               ...
# 975       Reviewed in the United States July 1, 2024
# 976      Reviewed in the United States July 22, 2024
# 977      Reviewed in the United States April 8, 2024
# 978     Reviewed in the United States April 12, 2024
# 979       Reviewed in the United States June 3, 2024
#
#                        profile_id  is_verified  helpful_count  \
# 880  AELFZXV7CNAJY5QEDRPA7YXBUGDQ         True              0
# 881  AF5F2GNRXCRVAOOCW36TN7IGGNWA         True             40
# 882  AEGRAUUKUO3JGDSH3IXQVSAXPH5A         True              2
# 883  AHFFS52VKVXLX27S2JJMXWFDQ5AA         True             55
# 884  AFIUWEUUEJPYZ2Z6F3WRP6TBHVOA         True              1
# ..                            ...          ...            ...
# 975  AENAPJJYOJ7TR4MZAJG3YFTUB56Q         True              0
# 976  AFI2XHUXHAEC2UEKHBCVQFFN2ZNA         True              0
# 977  AH76KIHCL4ZFNLMG7ERZYHEIVW5Q         True              1
# 978  AH5RKH5FKM3D5RDTEZXJVDRZIYEQ         True              2
# 979  AG7NKFXCXRC3Z3DHA2ZXXCOQ2YXQ         True              0
#
#     product_attributes
# 880                NaN
# 881                NaN
# 882                NaN
# 883                NaN
# 884                NaN
# ..                 ...
# 975                NaN
# 976                NaN
# 977                NaN
# 978                NaN
# 979                NaN
#
# [100 rows x 11 columns]

# %%
# This code cheks if there is any occurence of 'NaN' or 'Null' where the 'product_id' column is not equal to 'B09PMYTJD2'
df[(df['product_attributes'].isnull()) & (df['product_id'] != 'B09PMYTJD2')]
# Out:
# Empty DataFrame
# Columns: [review_id, product_id, title, author, rating, content, timestamp, profile_id, is_verified, helpful_count, product_attributes]
# Index: []

# %%
# filtering 'product_id' column
df.product_id
# Out:
# 0       B0D4SX9RC6
# 1       B0D4SX9RC6
# 2       B0D4SX9RC6
# 3       B0D4SX9RC6
# 4       B0D4SX9RC6
#            ...
# 1075    B07DD3WBYW
# 1076    B07DD3WBYW
# 1077    B07DD3WBYW
# 1078    B07DD3WBYW
# 1079    B07DD3WBYW
# Name: product_id, Length: 1080, dtype: object

# %%
# filtering 'product_id' column for unique values
df.product_id.unique()
# Out:
# array(['B0D4SX9RC6', 'B0BSNZJGTX', 'B07P39MLKH', 'B08YRT9T38',
#        'B099TJGJ91', 'B0CP7YLJ21', 'B08ZNXW53L', 'B09XXW54QG',
#        'B086D4JNGM', 'B0B43Y8GHZ', 'B09PMYTJD2', 'B07DD3WBYW'],
#       dtype=object)

# %%
# filtering column for unique values in 'product_attribute' column
df.product_attributes.unique()
# Out:
# array(['Color: Statement RedStyle: PillPattern: Without AppleCare+',
#        'Color: Champagne GoldStyle: PillPattern: Without AppleCare+',
#        'Color: Matte BlackStyle: PillPattern: Without AppleCare+',
#        'Color: Black', 'Color: Steel Grey', 'Color: Red',
#        'Color: Real Tree Camo', 'Color: NavyStyle: Bluetooth speaker',
#        'Color: Grey MistStyle: Bluetooth speaker',
#        'Color: Black AnthraciteStyle: Bluetooth speaker',
#        'Color: GreenStyle: Bluetooth speaker',
#        'Color: ChestnutStyle: Bluetooth speaker', 'Color: Stone Blue',
#        'Color: White Smoke', 'Color: Cypress Green',
#        'Color: Chilled Lilac', 'Color: Gray', 'Color: Gold',
#        'Style: Charge 5 + Divvi CaseColor: Squad',
#        'Style: Charge 5 + Divvi CaseColor: Blue',
#        'Style: Charge 5 + Divvi CaseColor: Black',
#        'Style: Charge 5 + Divvi CaseColor: Red',
#        'Style: Charge 5 + Divvi CaseColor: Teal',
#        'Style: Charge 5 + Divvi CaseColor: Gray',
#        'Color: Black & BrassStyle: Emberton II',
#        'Color: BlackStyle: Emberton', 'Color: CreamStyle: Emberton II',
#        'Color: Blue', 'Color: Taupe', 'Color: BlackStyle: SRSXG300/B',
#        'Color: BlackStyle: SRSXG500',
#        'Color: Light GrayStyle: SRSXG300/H', nan,
#        'Color: Night BlackPattern: Speaker',
#        'Color: Lagoon BluePattern: Speaker',
#        'Color: Sunset RedPattern: Speaker',
#        'Color: Ultraviolet PurplePattern: Speaker'], dtype=object)

# %%
# Check the data types of each of the column
df.dtypes
# Out:
# review_id             object
# product_id            object
# title                 object
# author                object
# rating                 int64
# content               object
# timestamp             object
# profile_id            object
# is_verified             bool
# helpful_count          int64
# product_attributes    object
# dtype: object

# %%
# Check teh following columns: product_id, title, rating, content, is_verified
df[['product_id', 'title', 'rating', 'content', 'is_verified']]
# Out:
#       product_id                                              title  rating  \
# 0     B0D4SX9RC6  5.0 out of 5 stars Really nice portable speake...       5
# 1     B0D4SX9RC6                      5.0 out of 5 stars Very Happy       5
# 2     B0D4SX9RC6  5.0 out of 5 stars The best Speaker I have eve...       5
# 3     B0D4SX9RC6                     5.0 out of 5 stars Really good       5
# 4     B0D4SX9RC6           4.0 out of 5 stars Is it the JBL killer?       4
# ...          ...                                                ...     ...
# 1075  B07DD3WBYW      2.0 out of 5 stars Sounds is muddy, micro-USB       2
# 1076  B07DD3WBYW                    5.0 out of 5 stars Good soeaker       5
# 1077  B07DD3WBYW   5.0 out of 5 stars Idiot proof and a great sound       5
# 1078  B07DD3WBYW  3.0 out of 5 stars Nice little speaker, but mi...       3
# 1079  B07DD3WBYW  5.0 out of 5 stars Love these, added a small o...       5
#
#                                                 content  is_verified
# 0     Needed a new portable speaker for the home set...         True
# 1     We bought this for a trip to the beach and it ...         True
# 2     I really like the new Beats Pill 2024 speaker....         True
# 3     So I’m super picky about sound and have spent ...         True
# 4     I bought this because it was on sale, and I al...         True
# ...                                                 ...          ...
# 1075  The micro-usb port caught me off guard. I trie...         True
# 1076  My husband loves it! It is portable and very g...         True
# 1077  1. Great sounds.2. Designed for fools (like me...         True
# 1078  This is a great travel speaker with one big fl...         True
# 1079  I have always loved the UE boom and rec it to ...         True
#
# [1080 rows x 5 columns]

# %%
# check where the is_verified value is false
df[df['is_verified'] == False]
# Out:
#           review_id  product_id  \
# 51   R2OYAX691GNN4K  B0D4SX9RC6
# 53   R3A0CT3JVYDFX3  B0D4SX9RC6
# 54   R31FPPEOE54HHH  B0D4SX9RC6
# 55   R1IDSWYH8GDHSG  B0D4SX9RC6
# 56   R310R8ZFHHHBI7  B0D4SX9RC6
# ..              ...         ...
# 475  R2YER5RV04CZ74  B0CP7YLJ21
# 476   RBPITYT3BLGJD  B0CP7YLJ21
# 477  R2175Z1F3RWMDA  B0CP7YLJ21
# 478  R3JO8WCN3AOUR3  B0CP7YLJ21
# 479  R3VSPQWFC53BWQ  B0CP7YLJ21
#
#                                                  title              author  \
# 51   5.0 out of 5 stars One of the Best Compact Por...       Student Nurse
# 53                       4.0 out of 5 stars Bass Heavy           Geomancer
# 54            4.0 out of 5 stars Not bad for the price        M.J. Shearer
# 55   5.0 out of 5 stars Beats pill returned with an...                Alan
# 56   5.0 out of 5 stars Pairs in stereo while "Roam...               jdawz
# ..                                                 ...                 ...
# 475   5.0 out of 5 stars I want to give this TEN STARS      Howard Abraham
# 476                      5.0 out of 5 stars Rich Sound                Tone
# 477                         5.0 out of 5 stars Speaker        Veldatheresa
# 478  5.0 out of 5 stars What an amazing sounding sp...  JAMES VANDERSCHAAF
# 479       3.0 out of 5 stars Loud, bass heavy tabletop             E.Swope
#
#      rating                                            content  \
# 51        5  I picked this up at the Apple Store the other ...
# 53        4  As you can probably tell from the product desc...
# 54        4  I own a plethora of bluetooth speakers, one ev...
# 55        5  This is a very small and compact speaker, but ...
# 56        5  Bought two JBL Flip 6's and was wowed with the...
# ..      ...                                                ...
# 475       5  The media could not be loaded. I had no idea a...
# 476       5  The media could not be loaded. This soundbox u...
# 477       5  Studio quality sound! The bass sounds impeccab...
# 478       5  The media could not be loaded. The speaker loo...
# 479       3  I should preference my review by saying that m...
#
#                                            timestamp  \
# 51   Reviewed in the United States September 4, 2024
# 53       Reviewed in the United States June 28, 2024
# 54       Reviewed in the United States July 10, 2024
# 55        Reviewed in the United States July 1, 2024
# 56   Reviewed in the United States September 3, 2024
# ..                                               ...
# 475     Reviewed in the United States March 15, 2024
# 476  Reviewed in the United States February 29, 2024
# 477      Reviewed in the United States March 5, 2024
# 478     Reviewed in the United States March 10, 2024
# 479      Reviewed in the United States March 8, 2024
#
#                        profile_id  is_verified  helpful_count  \
# 51   AFTRAIYZ5AITM2MEV2H2DNAHW73Q        False              0
# 53   AHS6VNLQVHWZLOI3RZ6ZXUWPK4OA        False             12
# 54   AFIPEJWLO34BKCROKOXTQOTHWOIQ        False              1
# 55   AFASPTXSH53KJIWIFP33WH2XDYXA        False              1
# 56   AFNED7OI2U3V2GPP6XHXMYQY5R6Q        False              0
# ..                            ...          ...            ...
# 475  AF7AXIIL5CI7A6OLJMMNMCTJCDTA        False             15
# 476  AHHGJIR6Z37OS7DSS32WGAB7KY3Q        False              3
# 477  AEJU3Z6HDAERETMYI2CXBQVPPDFA        False              0
# 478  AGL4QCERHNPCLTHTCSBGQ4WROZXA        False              0
# 479  AGASAFHLQKQP7RNG76TKN4GPBJBQ        False              0
#
#                                     product_attributes
# 51   Color: Matte BlackStyle: PillPattern: Without ...
# 53   Color: Matte BlackStyle: PillPattern: Without ...
# 54   Color: Matte BlackStyle: PillPattern: Without ...
# 55   Color: Matte BlackStyle: PillPattern: Without ...
# 56   Color: Matte BlackStyle: PillPattern: Without ...
# ..                                                 ...
# 475                                        Color: Gray
# 476                                        Color: Gold
# 477                                       Color: Black
# 478                                        Color: Gray
# 479                                        Color: Gold
#
# [92 rows x 11 columns]

# %%
df.iloc[70]
# Out:
# review_id                                                R1WGS76J7H1664
# product_id                                                   B0D4SX9RC6
# title                 5.0 out of 5 stars Overpriced IMO, but excelle...
# author                                                    Prefectionist
# rating                                                                5
# content               With any product that is this new, it's diffic...
# timestamp                    Reviewed in the United States July 5, 2024
# profile_id                                 AEP6LM43MWCBTOGT3APWMVNVVHJQ
# is_verified                                                       False
# helpful_count                                                         0
# product_attributes    Color: Matte BlackStyle: PillPattern: Without ...
# Name: 70, dtype: object

# %% [markdown]
# # Now, we clean the data. Sections with Nan or NULL

# %%
# calculating rows with null using isnull() method
df.isnull().sum()
# Out:
# review_id               0
# product_id              0
# title                   0
# author                  0
# rating                  0
# content                 0
# timestamp               0
# profile_id              0
# is_verified             0
# helpful_count           0
# product_attributes    100
# dtype: int64

# %%
# filling the values of NaN with the value 'Color: Black' into a duplicate DataFrame and working with that duplicate
df_filled = df.fillna({'product_attributes':'Color: Black'})
df_filled.head()
# Out:
#         review_id  product_id  \
# 0  R2SSSH04J4J264  B0D4SX9RC6
# 1   R935PCZ92UVGL  B0D4SX9RC6
# 2   R4BQHA0TLLJNN  B0D4SX9RC6
# 3  R39X7USU3OX34C  B0D4SX9RC6
# 4  R2EVRTXO9M1YF7  B0D4SX9RC6
#
#                                                title     author  rating  \
# 0  5.0 out of 5 stars Really nice portable speake...    Bruce C       5
# 1                      5.0 out of 5 stars Very Happy  B. Hinson       5
# 2  5.0 out of 5 stars The best Speaker I have eve...       Leox       5
# 3                     5.0 out of 5 stars Really good     Justin       5
# 4           4.0 out of 5 stars Is it the JBL killer?      Tommy       4
#
#                                              content  \
# 0  Needed a new portable speaker for the home set...
# 1  We bought this for a trip to the beach and it ...
# 2  I really like the new Beats Pill 2024 speaker....
# 3  So I’m super picky about sound and have spent ...
# 4  I bought this because it was on sale, and I al...
#
#                                          timestamp  \
# 0       Reviewed in the United States July 1, 2024
# 1  Reviewed in the United States September 5, 2024
# 2      Reviewed in the United States July 11, 2024
# 3       Reviewed in the United States July 8, 2024
# 4      Reviewed in the United States July 23, 2024
#
#                      profile_id  is_verified  helpful_count  \
# 0  AFVM53KRAU5JC462ZZDBBKTESPGA         True             18
# 1  AFPN35SDBWBDQAGNSNQJQPQH5C2Q         True              0
# 2  AEUCX7EIPTMCFN4OJBZHL2OYSVKQ         True              8
# 3  AFSZPNTTLYCLNP536L6VS6UMFTNQ         True              7
# 4  AHAMVBSECCNUJMQV6A3BO3A3HNMA         True              5
#
#                                   product_attributes
# 0  Color: Statement RedStyle: PillPattern: Withou...
# 1  Color: Champagne GoldStyle: PillPattern: Witho...
# 2  Color: Champagne GoldStyle: PillPattern: Witho...
# 3  Color: Statement RedStyle: PillPattern: Withou...
# 4  Color: Matte BlackStyle: PillPattern: Without ...

# %%
# Rechecking for the values of null again
df_filled[df_filled['product_attributes'].isnull()]
# Out:
# Empty DataFrame
# Columns: [review_id, product_id, title, author, rating, content, timestamp, profile_id, is_verified, helpful_count, product_attributes]
# Index: []

# %%
# Checking for the product id with the previous null values
df_filled[df_filled['product_id']=='B09PMYTJD2']
# Out:
#           review_id  product_id  \
# 880   RI4J0OA8QEHX8  B09PMYTJD2
# 881    REPT12N1Z65B  B09PMYTJD2
# 882  R2D4M42M5NELUB  B09PMYTJD2
# 883   RZN1X5HHIPU79  B09PMYTJD2
# 884   RWUVNJD6SC9JC  B09PMYTJD2
# ..              ...         ...
# 975   R1ETA2URW8F7Z  B09PMYTJD2
# 976  R327YT3BDZYU7P  B09PMYTJD2
# 977  R1XWYTWY3KZHT4  B09PMYTJD2
# 978  R1VG7FOEEHQUJJ  B09PMYTJD2
# 979   RQAC8XTGY3I9T  B09PMYTJD2
#
#                                                  title              author  \
# 880       5.0 out of 5 stars Simply top of its class!!      Dr. Ace Farley
# 881           5.0 out of 5 stars Tribit Stormbox Blast                BLRG
# 882                   5.0 out of 5 stars Awesome Sound  Ryan Nobles-Fisher
# 883  5.0 out of 5 stars Unbeatable price/performanc...             Corndog
# 884           4.0 out of 5 stars Great initial quality      SuperBlindGirl
# ..                                                 ...                 ...
# 975                    5.0 out of 5 stars Good Product                 Leo
# 976    3.0 out of 5 stars Decent product for basic use           Boxranger
# 977            5.0 out of 5 stars Exceptionally good 🔊                   T
# 978                               5.0 out of 5 stars 🫠     SumtingSumwhere
# 979                        4.0 out of 5 stars 4/5 star            unlisted
#
#      rating                                            content  \
# 880       5  This Stormbox blast is simply the benchmark in...
# 881       5  Arrived yesterday and connected it straight aw...
# 882       5  Was considering this or the JBL equivalent, bu...
# 883       5  Sure, it's a bit weighty, but I'd rather that ...
# 884       4  Writing this review from one blind person's pe...
# ..      ...                                                ...
# 975       5                                   Very good sound.
# 976       3  I liked the weight and construction of the uni...
# 977       5  This speaker is absolutely perfect. It sounds ...
# 978       5  The media could not be loaded. OMFG.Listen, yo...
# 979       4  Great sound would be 5/5 but controls are limi...
#
#                                            timestamp  \
# 880    Reviewed in the United States August 27, 2024
# 881  Reviewed in the United States September 1, 2023
# 882    Reviewed in the United States August 15, 2024
# 883    Reviewed in the United States January 9, 2023
# 884    Reviewed in the United States August 27, 2024
# ..                                               ...
# 975       Reviewed in the United States July 1, 2024
# 976      Reviewed in the United States July 22, 2024
# 977      Reviewed in the United States April 8, 2024
# 978     Reviewed in the United States April 12, 2024
# 979       Reviewed in the United States June 3, 2024
#
#                        profile_id  is_verified  helpful_count  \
# 880  AELFZXV7CNAJY5QEDRPA7YXBUGDQ         True              0
# 881  AF5F2GNRXCRVAOOCW36TN7IGGNWA         True             40
# 882  AEGRAUUKUO3JGDSH3IXQVSAXPH5A         True              2
# 883  AHFFS52VKVXLX27S2JJMXWFDQ5AA         True             55
# 884  AFIUWEUUEJPYZ2Z6F3WRP6TBHVOA         True              1
# ..                            ...          ...            ...
# 975  AENAPJJYOJ7TR4MZAJG3YFTUB56Q         True              0
# 976  AFI2XHUXHAEC2UEKHBCVQFFN2ZNA         True              0
# 977  AH76KIHCL4ZFNLMG7ERZYHEIVW5Q         True              1
# 978  AH5RKH5FKM3D5RDTEZXJVDRZIYEQ         True              2
# 979  AG7NKFXCXRC3Z3DHA2ZXXCOQ2YXQ         True              0
#
#     product_attributes
# 880       Color: Black
# 881       Color: Black
# 882       Color: Black
# 883       Color: Black
# 884       Color: Black
# ..                 ...
# 975       Color: Black
# 976       Color: Black
# 977       Color: Black
# 978       Color: Black
# 979       Color: Black
#
# [100 rows x 11 columns]

# %% [markdown]
# 2. Creating new columns for Product brand names and product prices

# %%
# Creating a column with the product brand name

asin = {
          'B0D4SX9RC6': 'Beats Pill Speaker',
          'B09XXW54QG': 'Marshall Emberton II Speaker',
           'B099TJGJ91': 'Bose SoundLink Flex Speaker',
           'B08ZNXW53L': 'JBL Charge 5 Speaker',
           'B07DD3WBYW':'Ultimate Ears Boom 3 Speaker',
           'B07P39MLKH': 'Anker Soundcore Motion+ Speaker',
           'B086D4JNGM': 'Sony SRS-XB33 Extra Bass Speaker',
           'B0B43Y8GHZ': 'Sony SRS-XG300 X-Series Party-Speaker',
           'B09PMYTJD2': 'Tribit StormBox Pro Speaker',
           'B08YRT9T38': 'Bang & Olufsen Beosound Outdoor speaker',
           'B0CP7YLJ21': 'DOSS SoundBox Plus Speaker',
           'B0BSNZJGTX': 'Altec Lansing Rockbox XL 2.0 Speakers'
          }
df_filled['product_brand_name'] = df_filled['product_id'].apply(lambda x: asin[x] if x in asin else "No Product")

# %%
df_filled.head()
# Out:
#         review_id  product_id  \
# 0  R2SSSH04J4J264  B0D4SX9RC6
# 1   R935PCZ92UVGL  B0D4SX9RC6
# 2   R4BQHA0TLLJNN  B0D4SX9RC6
# 3  R39X7USU3OX34C  B0D4SX9RC6
# 4  R2EVRTXO9M1YF7  B0D4SX9RC6
#
#                                                title     author  rating  \
# 0  5.0 out of 5 stars Really nice portable speake...    Bruce C       5
# 1                      5.0 out of 5 stars Very Happy  B. Hinson       5
# 2  5.0 out of 5 stars The best Speaker I have eve...       Leox       5
# 3                     5.0 out of 5 stars Really good     Justin       5
# 4           4.0 out of 5 stars Is it the JBL killer?      Tommy       4
#
#                                              content  \
# 0  Needed a new portable speaker for the home set...
# 1  We bought this for a trip to the beach and it ...
# 2  I really like the new Beats Pill 2024 speaker....
# 3  So I’m super picky about sound and have spent ...
# 4  I bought this because it was on sale, and I al...
#
#                                          timestamp  \
# 0       Reviewed in the United States July 1, 2024
# 1  Reviewed in the United States September 5, 2024
# 2      Reviewed in the United States July 11, 2024
# 3       Reviewed in the United States July 8, 2024
# 4      Reviewed in the United States July 23, 2024
#
#                      profile_id  is_verified  helpful_count  \
# 0  AFVM53KRAU5JC462ZZDBBKTESPGA         True             18
# 1  AFPN35SDBWBDQAGNSNQJQPQH5C2Q         True              0
# 2  AEUCX7EIPTMCFN4OJBZHL2OYSVKQ         True              8
# 3  AFSZPNTTLYCLNP536L6VS6UMFTNQ         True              7
# 4  AHAMVBSECCNUJMQV6A3BO3A3HNMA         True              5
#
#                                   product_attributes  product_brand_name
# 0  Color: Statement RedStyle: PillPattern: Withou...  Beats Pill Speaker
# 1  Color: Champagne GoldStyle: PillPattern: Witho...  Beats Pill Speaker
# 2  Color: Champagne GoldStyle: PillPattern: Witho...  Beats Pill Speaker
# 3  Color: Statement RedStyle: PillPattern: Withou...  Beats Pill Speaker
# 4  Color: Matte BlackStyle: PillPattern: Without ...  Beats Pill Speaker

# %%
# filtering column for the count of values for each product name
df_filled['product_brand_name'].value_counts()
# Out:
# product_brand_name
# Altec Lansing Rockbox XL 2.0 Speakers      100
# Anker Soundcore Motion+ Speaker            100
# Bang & Olufsen Beosound Outdoor speaker    100
# Marshall Emberton II Speaker               100
# Tribit StormBox Pro Speaker                100
# JBL Charge 5 Speaker                       100
# Sony SRS-XG300 X-Series Party-Speaker      100
# Sony SRS-XB33 Extra Bass Speaker           100
# Ultimate Ears Boom 3 Speaker               100
# Beats Pill Speaker                          85
# DOSS SoundBox Plus Speaker                  85
# Bose SoundLink Flex Speaker                 10
# Name: count, dtype: int64

# %%
# Creating a column with the product prices
price = {
          'B0D4SX9RC6': 149.95,
          'B09XXW54QG': 115.08,
           'B099TJGJ91': 149.00,
           'B08ZNXW53L': 179.95,
           'B07DD3WBYW': 125.10,
           'B07P39MLKH': 99.99,
           'B086D4JNGM': 149.95,
           'B0B43Y8GHZ': 198.00,
           'B09PMYTJD2': 199.99,
           'B08YRT9T38': 195.58,
           'B0CP7YLJ21': 159.99,
           'B0BSNZJGTX': 129.99
          }
df_filled['product_price($)'] = df_filled['product_id'].apply(lambda x: price[x] if x in asin else "No Product")

# %%
df_filled.head()
# Out:
#         review_id  product_id  \
# 0  R2SSSH04J4J264  B0D4SX9RC6
# 1   R935PCZ92UVGL  B0D4SX9RC6
# 2   R4BQHA0TLLJNN  B0D4SX9RC6
# 3  R39X7USU3OX34C  B0D4SX9RC6
# 4  R2EVRTXO9M1YF7  B0D4SX9RC6
#
#                                                title     author  rating  \
# 0  5.0 out of 5 stars Really nice portable speake...    Bruce C       5
# 1                      5.0 out of 5 stars Very Happy  B. Hinson       5
# 2  5.0 out of 5 stars The best Speaker I have eve...       Leox       5
# 3                     5.0 out of 5 stars Really good     Justin       5
# 4           4.0 out of 5 stars Is it the JBL killer?      Tommy       4
#
#                                              content  \
# 0  Needed a new portable speaker for the home set...
# 1  We bought this for a trip to the beach and it ...
# 2  I really like the new Beats Pill 2024 speaker....
# 3  So I’m super picky about sound and have spent ...
# 4  I bought this because it was on sale, and I al...
#
#                                          timestamp  \
# 0       Reviewed in the United States July 1, 2024
# 1  Reviewed in the United States September 5, 2024
# 2      Reviewed in the United States July 11, 2024
# 3       Reviewed in the United States July 8, 2024
# 4      Reviewed in the United States July 23, 2024
#
#                      profile_id  is_verified  helpful_count  \
# 0  AFVM53KRAU5JC462ZZDBBKTESPGA         True             18
# 1  AFPN35SDBWBDQAGNSNQJQPQH5C2Q         True              0
# 2  AEUCX7EIPTMCFN4OJBZHL2OYSVKQ         True              8
# 3  AFSZPNTTLYCLNP536L6VS6UMFTNQ         True              7
# 4  AHAMVBSECCNUJMQV6A3BO3A3HNMA         True              5
#
#                                   product_attributes  product_brand_name  \
# 0  Color: Statement RedStyle: PillPattern: Withou...  Beats Pill Speaker
# 1  Color: Champagne GoldStyle: PillPattern: Witho...  Beats Pill Speaker
# 2  Color: Champagne GoldStyle: PillPattern: Witho...  Beats Pill Speaker
# 3  Color: Statement RedStyle: PillPattern: Withou...  Beats Pill Speaker
# 4  Color: Matte BlackStyle: PillPattern: Without ...  Beats Pill Speaker
#
#    product_price($)
# 0            149.95
# 1            149.95
# 2            149.95
# 3            149.95
# 4            149.95

# %%
# filtering column for the count of values for each product price
df_filled['product_price($)'].value_counts()
# Out:
# product_price($)
# 149.95    185
# 129.99    100
# 99.99     100
# 195.58    100
# 179.95    100
# 198.00    100
# 115.08    100
# 199.99    100
# 125.10    100
# 159.99     85
# 149.00     10
# Name: count, dtype: int64

# %%
# Checking for any occurence of 'No product' based on the code used to create new columns for product brand names and product brand prices
df_filled[(df_filled['product_price($)']=='No Product') | (df_filled['product_brand_name']=='No Product')]
# Out:
# Empty DataFrame
# Columns: [review_id, product_id, title, author, rating, content, timestamp, profile_id, is_verified, helpful_count, product_attributes, product_brand_name, product_price($)]
# Index: []

# %% [markdown]
# 3. Deleting personal data gathered

# %%
# personal data collected from the product reviews
df_filled.author
# Out:
# 0                 Bruce C
# 1               B. Hinson
# 2                    Leox
# 3                  Justin
# 4                   Tommy
#               ...
# 1075             Walter W
# 1076                  Ana
# 1077                Cindy
# 1078    Noah Libby-Haines
# 1079                Nigel
# Name: author, Length: 1080, dtype: object

# %%
# Dropping a column
df_filled.drop('author', axis=1, inplace=True)

# %%
# Viewing all different columns to check if there is still an 'author' column
df_filled.columns
# Out:
# Index(['review_id', 'product_id', 'title', 'rating', 'content', 'timestamp',
#        'profile_id', 'is_verified', 'helpful_count', 'product_attributes',
#        'product_brand_name', 'product_price($)'],
#       dtype='object')

# %% [markdown]
# 4. Separating values in a column into a different column

# %%
# The column we are working on
df_filled.title
# Out:
# 0       5.0 out of 5 stars Really nice portable speake...
# 1                           5.0 out of 5 stars Very Happy
# 2       5.0 out of 5 stars The best Speaker I have eve...
# 3                          5.0 out of 5 stars Really good
# 4                4.0 out of 5 stars Is it the JBL killer?
#                               ...
# 1075        2.0 out of 5 stars Sounds is muddy, micro-USB
# 1076                      5.0 out of 5 stars Good soeaker
# 1077     5.0 out of 5 stars Idiot proof and a great sound
# 1078    3.0 out of 5 stars Nice little speaker, but mi...
# 1079    5.0 out of 5 stars Love these, added a small o...
# Name: title, Length: 1080, dtype: object

# %%
# Separating the rating in 'title' column and creating another column with just the comments in the 'title' column to another new column called 'titles' using the string index to truncate it.
df_filled['titles'] = df_filled['title'].apply(lambda x: x[19:])
print(df_filled['titles'])
# Out:
# 0       Really nice portable speaker for the price. So...
# 1                                              Very Happy
# 2         The best Speaker I have ever bought in my life!
# 3                                             Really good
# 4                                   Is it the JBL killer?
#                               ...
# 1075                           Sounds is muddy, micro-USB
# 1076                                         Good soeaker
# 1077                        Idiot proof and a great sound
# 1078          Nice little speaker, but micro USB? Really?
# 1079       Love these, added a small one to my collection
# Name: titles, Length: 1080, dtype: object

# %%
# printing both 'title' and 'titles'
df_filled[['title', 'titles']]
# Out:
#                                                   title  \
# 0     5.0 out of 5 stars Really nice portable speake...
# 1                         5.0 out of 5 stars Very Happy
# 2     5.0 out of 5 stars The best Speaker I have eve...
# 3                        5.0 out of 5 stars Really good
# 4              4.0 out of 5 stars Is it the JBL killer?
# ...                                                 ...
# 1075      2.0 out of 5 stars Sounds is muddy, micro-USB
# 1076                    5.0 out of 5 stars Good soeaker
# 1077   5.0 out of 5 stars Idiot proof and a great sound
# 1078  3.0 out of 5 stars Nice little speaker, but mi...
# 1079  5.0 out of 5 stars Love these, added a small o...
#
#                                                  titles
# 0     Really nice portable speaker for the price. So...
# 1                                            Very Happy
# 2       The best Speaker I have ever bought in my life!
# 3                                           Really good
# 4                                 Is it the JBL killer?
# ...                                                 ...
# 1075                         Sounds is muddy, micro-USB
# 1076                                       Good soeaker
# 1077                      Idiot proof and a great sound
# 1078        Nice little speaker, but micro USB? Really?
# 1079     Love these, added a small one to my collection
#
# [1080 rows x 2 columns]

# %%
# Dropping a column since the values are separated into different column
df_filled.drop('title', axis=1, inplace=True)

# %% [markdown]
# 5. Converting Boolean values to numerical data (binary)

# %%
# Checking for boolean values
df_filled.is_verified
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1075    True
# 1076    True
# 1077    True
# 1078    True
# 1079    True
# Name: is_verified, Length: 1080, dtype: bool

# %%
# creating a new column where churn boolean values become binary in new column
df_filled['verified_binary'] = df_filled['is_verified'].apply(lambda x: 1 if x==True else 0)
df_filled.verified_binary
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1075    1
# 1076    1
# 1077    1
# 1078    1
# 1079    1
# Name: verified_binary, Length: 1080, dtype: int64

# %%
df_filled[['is_verified', 'verified_binary']]
# Out:
#       is_verified  verified_binary
# 0            True                1
# 1            True                1
# 2            True                1
# 3            True                1
# 4            True                1
# ...           ...              ...
# 1075         True                1
# 1076         True                1
# 1077         True                1
# 1078         True                1
# 1079         True                1
#
# [1080 rows x 2 columns]

# %% [markdown]
# 6. Separating the values in the 'timestamp' column and creating a new column with the date in the timestamp column

# %%
# Checking timestamp column format
df_filled.timestamp
# Out:
# 0            Reviewed in the United States July 1, 2024
# 1       Reviewed in the United States September 5, 2024
# 2           Reviewed in the United States July 11, 2024
# 3            Reviewed in the United States July 8, 2024
# 4           Reviewed in the United States July 23, 2024
#                              ...
# 1075         Reviewed in the United States May 25, 2024
# 1076    Reviewed in the United States February 28, 2024
# 1077    Reviewed in the United States November 25, 2023
# 1078      Reviewed in the United States January 4, 2024
# 1079     Reviewed in the United States October 22, 2023
# Name: timestamp, Length: 1080, dtype: object

# %%
# Assuming the date is always at the end of the string, split the string values from the column 'timestamp' and create a new column containing only the dates
df_filled['date_extracted'] = df_filled['timestamp'].str.split('Reviewed in the United States').str[-1].str.strip()
df_filled['date_extracted'] = pd.to_datetime(df_filled['date_extracted'])
df_filled[['timestamp', 'date_extracted']]
# Out:
#                                             timestamp date_extracted
# 0          Reviewed in the United States July 1, 2024     2024-07-01
# 1     Reviewed in the United States September 5, 2024     2024-09-05
# 2         Reviewed in the United States July 11, 2024     2024-07-11
# 3          Reviewed in the United States July 8, 2024     2024-07-08
# 4         Reviewed in the United States July 23, 2024     2024-07-23
# ...                                               ...            ...
# 1075       Reviewed in the United States May 25, 2024     2024-05-25
# 1076  Reviewed in the United States February 28, 2024     2024-02-28
# 1077  Reviewed in the United States November 25, 2023     2023-11-25
# 1078    Reviewed in the United States January 4, 2024     2024-01-04
# 1079   Reviewed in the United States October 22, 2023     2023-10-22
#
# [1080 rows x 2 columns]

# %%
# for checking the names of all columns in the dataframe
df_filled.columns
# Out:
# Index(['review_id', 'product_id', 'rating', 'content', 'timestamp',
#        'profile_id', 'is_verified', 'helpful_count', 'product_attributes',
#        'product_brand_name', 'product_price($)', 'titles', 'verified_binary',
#        'date_extracted'],
#       dtype='object')

# %%
# for checking data types of all columns
df_filled.dtypes
# Out:
# review_id                     object
# product_id                    object
# rating                         int64
# content                       object
# timestamp                     object
# profile_id                    object
# is_verified                     bool
# helpful_count                  int64
# product_attributes            object
# product_brand_name            object
# product_price($)             float64
# titles                        object
# verified_binary                int64
# date_extracted        datetime64[ns]
# dtype: object

# %% [markdown]
# 7 Separating the values in the 'product_attributes' column, splitting the color values into a new column.

# %%
# filtering column for unique values
df_filled.product_attributes.unique()
# Out:
# array(['Color: Statement RedStyle: PillPattern: Without AppleCare+',
#        'Color: Champagne GoldStyle: PillPattern: Without AppleCare+',
#        'Color: Matte BlackStyle: PillPattern: Without AppleCare+',
#        'Color: Black', 'Color: Steel Grey', 'Color: Red',
#        'Color: Real Tree Camo', 'Color: NavyStyle: Bluetooth speaker',
#        'Color: Grey MistStyle: Bluetooth speaker',
#        'Color: Black AnthraciteStyle: Bluetooth speaker',
#        'Color: GreenStyle: Bluetooth speaker',
#        'Color: ChestnutStyle: Bluetooth speaker', 'Color: Stone Blue',
#        'Color: White Smoke', 'Color: Cypress Green',
#        'Color: Chilled Lilac', 'Color: Gray', 'Color: Gold',
#        'Style: Charge 5 + Divvi CaseColor: Squad',
#        'Style: Charge 5 + Divvi CaseColor: Blue',
#        'Style: Charge 5 + Divvi CaseColor: Black',
#        'Style: Charge 5 + Divvi CaseColor: Red',
#        'Style: Charge 5 + Divvi CaseColor: Teal',
#        'Style: Charge 5 + Divvi CaseColor: Gray',
#        'Color: Black & BrassStyle: Emberton II',
#        'Color: BlackStyle: Emberton', 'Color: CreamStyle: Emberton II',
#        'Color: Blue', 'Color: Taupe', 'Color: BlackStyle: SRSXG300/B',
#        'Color: BlackStyle: SRSXG500',
#        'Color: Light GrayStyle: SRSXG300/H',
#        'Color: Night BlackPattern: Speaker',
#        'Color: Lagoon BluePattern: Speaker',
#        'Color: Sunset RedPattern: Speaker',
#        'Color: Ultraviolet PurplePattern: Speaker'], dtype=object)

# %%
# Checking for data entries with the string 'Style' in the column 'product_attributes'
df_filled[df_filled['product_attributes'].str.contains('Style')]
# Out:
#           review_id  product_id  rating  \
# 0    R2SSSH04J4J264  B0D4SX9RC6       5
# 1     R935PCZ92UVGL  B0D4SX9RC6       5
# 2     R4BQHA0TLLJNN  B0D4SX9RC6       5
# 3    R39X7USU3OX34C  B0D4SX9RC6       5
# 4    R2EVRTXO9M1YF7  B0D4SX9RC6       4
# ..              ...         ...     ...
# 875  R1EQXVNQSI7ESF  B0B43Y8GHZ       5
# 876  R3MEQG3A5I1BXQ  B0B43Y8GHZ       5
# 877   R2514WBS66UHG  B0B43Y8GHZ       5
# 878  R3I7Z3PZKKH3J9  B0B43Y8GHZ       3
# 879  R16C3SVLG17M86  B0B43Y8GHZ       5
#
#                                                content  \
# 0    Needed a new portable speaker for the home set...
# 1    We bought this for a trip to the beach and it ...
# 2    I really like the new Beats Pill 2024 speaker....
# 3    So I’m super picky about sound and have spent ...
# 4    I bought this because it was on sale, and I al...
# ..                                                 ...
# 875  Works great has pretty good bass. batery takes...
# 876                                        Awesomeness
# 877  Great bass. This speaker has rich bass at any ...
# 878  The speaker doesn’t bump as loud as I want. Th...
# 879  This surprised me with how good it sounds. Has...
#
#                                             timestamp  \
# 0          Reviewed in the United States July 1, 2024
# 1     Reviewed in the United States September 5, 2024
# 2         Reviewed in the United States July 11, 2024
# 3          Reviewed in the United States July 8, 2024
# 4         Reviewed in the United States July 23, 2024
# ..                                                ...
# 875   Reviewed in the United States December 30, 2023
# 876    Reviewed in the United States February 9, 2024
# 877   Reviewed in the United States November 11, 2023
# 878   Reviewed in the United States November 16, 2023
# 879  Reviewed in the United States September 17, 2023
#
#                        profile_id  is_verified  helpful_count  \
# 0    AFVM53KRAU5JC462ZZDBBKTESPGA         True             18
# 1    AFPN35SDBWBDQAGNSNQJQPQH5C2Q         True              0
# 2    AEUCX7EIPTMCFN4OJBZHL2OYSVKQ         True              8
# 3    AFSZPNTTLYCLNP536L6VS6UMFTNQ         True              7
# 4    AHAMVBSECCNUJMQV6A3BO3A3HNMA         True              5
# ..                            ...          ...            ...
# 875  AFHJFB5VPNSCMQNCMMRTT2N6T6GA         True              0
# 876  AFDJZ2RCAAFMRS5DCW65SUSFWFVQ         True              0
# 877  AECYIM6W2I54KCO67UQ52XLOUQ3A         True              0
# 878  AECQR2ZZ57XRCW7NUKOOF3QSHX6A         True              0
# 879  AGN3AWPKYZPGMDB6RU6ZNO6PHT7Q         True              4
#
#                                     product_attributes  \
# 0    Color: Statement RedStyle: PillPattern: Withou...
# 1    Color: Champagne GoldStyle: PillPattern: Witho...
# 2    Color: Champagne GoldStyle: PillPattern: Witho...
# 3    Color: Statement RedStyle: PillPattern: Withou...
# 4    Color: Matte BlackStyle: PillPattern: Without ...
# ..                                                 ...
# 875                      Color: BlackStyle: SRSXG300/B
# 876                      Color: BlackStyle: SRSXG300/B
# 877                      Color: BlackStyle: SRSXG300/B
# 878                      Color: BlackStyle: SRSXG300/B
# 879                        Color: BlackStyle: SRSXG500
#
#                         product_brand_name  product_price($)  \
# 0                       Beats Pill Speaker            149.95
# 1                       Beats Pill Speaker            149.95
# 2                       Beats Pill Speaker            149.95
# 3                       Beats Pill Speaker            149.95
# 4                       Beats Pill Speaker            149.95
# ..                                     ...               ...
# 875  Sony SRS-XG300 X-Series Party-Speaker            198.00
# 876  Sony SRS-XG300 X-Series Party-Speaker            198.00
# 877  Sony SRS-XG300 X-Series Party-Speaker            198.00
# 878  Sony SRS-XG300 X-Series Party-Speaker            198.00
# 879  Sony SRS-XG300 X-Series Party-Speaker            198.00
#
#                                                 titles  verified_binary  \
# 0    Really nice portable speaker for the price. So...                1
# 1                                           Very Happy                1
# 2      The best Speaker I have ever bought in my life!                1
# 3                                          Really good                1
# 4                                Is it the JBL killer?                1
# ..                                                 ...              ...
# 875                                              Great                1
# 876                                        Awesomeness                1
# 877                                  Sounds incredible                1
# 878                       Barely meets my satisfaction                1
# 879                                  Damn good speaker                1
#
#     date_extracted
# 0       2024-07-01
# 1       2024-09-05
# 2       2024-07-11
# 3       2024-07-08
# 4       2024-07-23
# ..             ...
# 875     2023-12-30
# 876     2024-02-09
# 877     2023-11-11
# 878     2023-11-16
# 879     2023-09-17
#
# [485 rows x 14 columns]

# %%
# Checking for data entries with the string 'Pattern' in the column 'product_attributes'
df_filled[df_filled['product_attributes'].str.contains('Pattern')]
# Out:
#            review_id  product_id  rating  \
# 0     R2SSSH04J4J264  B0D4SX9RC6       5
# 1      R935PCZ92UVGL  B0D4SX9RC6       5
# 2      R4BQHA0TLLJNN  B0D4SX9RC6       5
# 3     R39X7USU3OX34C  B0D4SX9RC6       5
# 4     R2EVRTXO9M1YF7  B0D4SX9RC6       4
# ...              ...         ...     ...
# 1075  R2GI0V9SVJPRQ3  B07DD3WBYW       2
# 1076  R2MLWKC3JFNFDX  B07DD3WBYW       5
# 1077   RJEXLAFIRWWRD  B07DD3WBYW       5
# 1078   R40NGCH3W5BSQ  B07DD3WBYW       3
# 1079  R215G1OC4IVNBL  B07DD3WBYW       5
#
#                                                 content  \
# 0     Needed a new portable speaker for the home set...
# 1     We bought this for a trip to the beach and it ...
# 2     I really like the new Beats Pill 2024 speaker....
# 3     So I’m super picky about sound and have spent ...
# 4     I bought this because it was on sale, and I al...
# ...                                                 ...
# 1075  The micro-usb port caught me off guard. I trie...
# 1076  My husband loves it! It is portable and very g...
# 1077  1. Great sounds.2. Designed for fools (like me...
# 1078  This is a great travel speaker with one big fl...
# 1079  I have always loved the UE boom and rec it to ...
#
#                                             timestamp  \
# 0          Reviewed in the United States July 1, 2024
# 1     Reviewed in the United States September 5, 2024
# 2         Reviewed in the United States July 11, 2024
# 3          Reviewed in the United States July 8, 2024
# 4         Reviewed in the United States July 23, 2024
# ...                                               ...
# 1075       Reviewed in the United States May 25, 2024
# 1076  Reviewed in the United States February 28, 2024
# 1077  Reviewed in the United States November 25, 2023
# 1078    Reviewed in the United States January 4, 2024
# 1079   Reviewed in the United States October 22, 2023
#
#                         profile_id  is_verified  helpful_count  \
# 0     AFVM53KRAU5JC462ZZDBBKTESPGA         True             18
# 1     AFPN35SDBWBDQAGNSNQJQPQH5C2Q         True              0
# 2     AEUCX7EIPTMCFN4OJBZHL2OYSVKQ         True              8
# 3     AFSZPNTTLYCLNP536L6VS6UMFTNQ         True              7
# 4     AHAMVBSECCNUJMQV6A3BO3A3HNMA         True              5
# ...                            ...          ...            ...
# 1075  AHA4BS73C3MSQ3Y5NAFUCKMD4SGQ         True              0
# 1076  AGS455DZKBQHYHYTH2NPU5YUXHAQ         True              0
# 1077  AHHDFD2FOO7PYT6THV26ARUOB3GA         True              3
# 1078  AGQNTSI7GAPRHSXT6OA6WGWV2IRA         True              1
# 1079  AHPX4BSRV7LKSFC6EVI333VVJQGA         True              1
#
#                                      product_attributes  \
# 0     Color: Statement RedStyle: PillPattern: Withou...
# 1     Color: Champagne GoldStyle: PillPattern: Witho...
# 2     Color: Champagne GoldStyle: PillPattern: Witho...
# 3     Color: Statement RedStyle: PillPattern: Withou...
# 4     Color: Matte BlackStyle: PillPattern: Without ...
# ...                                                 ...
# 1075                 Color: Lagoon BluePattern: Speaker
# 1076                 Color: Night BlackPattern: Speaker
# 1077          Color: Ultraviolet PurplePattern: Speaker
# 1078                 Color: Night BlackPattern: Speaker
# 1079                 Color: Night BlackPattern: Speaker
#
#                 product_brand_name  product_price($)  \
# 0               Beats Pill Speaker            149.95
# 1               Beats Pill Speaker            149.95
# 2               Beats Pill Speaker            149.95
# 3               Beats Pill Speaker            149.95
# 4               Beats Pill Speaker            149.95
# ...                            ...               ...
# 1075  Ultimate Ears Boom 3 Speaker            125.10
# 1076  Ultimate Ears Boom 3 Speaker            125.10
# 1077  Ultimate Ears Boom 3 Speaker            125.10
# 1078  Ultimate Ears Boom 3 Speaker            125.10
# 1079  Ultimate Ears Boom 3 Speaker            125.10
#
#                                                  titles  verified_binary  \
# 0     Really nice portable speaker for the price. So...                1
# 1                                            Very Happy                1
# 2       The best Speaker I have ever bought in my life!                1
# 3                                           Really good                1
# 4                                 Is it the JBL killer?                1
# ...                                                 ...              ...
# 1075                         Sounds is muddy, micro-USB                1
# 1076                                       Good soeaker                1
# 1077                      Idiot proof and a great sound                1
# 1078        Nice little speaker, but micro USB? Really?                1
# 1079     Love these, added a small one to my collection                1
#
#      date_extracted
# 0        2024-07-01
# 1        2024-09-05
# 2        2024-07-11
# 3        2024-07-08
# 4        2024-07-23
# ...             ...
# 1075     2024-05-25
# 1076     2024-02-28
# 1077     2023-11-25
# 1078     2024-01-04
# 1079     2023-10-22
#
# [185 rows x 14 columns]

# %%
# Split by 'Color:' and get the part after 'Color:'
df_filled['color'] = df_filled['product_attributes'].str.split('Color:').str[1]

# Further split by 'Style:' or 'Pattern:'
df_filled['color'] = df_filled['color'].apply(lambda x: x.split('Style:')[0] if 'Style:' in x else x.split('Pattern:')[0])

# Strip leading/trailing spaces
df_filled['color'] = df_filled['color'].str.strip()

# Display the DataFrame
print(df_filled[['product_attributes', 'color']])
# Out:
#                                      product_attributes               color
# 0     Color: Statement RedStyle: PillPattern: Withou...       Statement Red
# 1     Color: Champagne GoldStyle: PillPattern: Witho...      Champagne Gold
# 2     Color: Champagne GoldStyle: PillPattern: Witho...      Champagne Gold
# 3     Color: Statement RedStyle: PillPattern: Withou...       Statement Red
# 4     Color: Matte BlackStyle: PillPattern: Without ...         Matte Black
# ...                                                 ...                 ...
# 1075                 Color: Lagoon BluePattern: Speaker         Lagoon Blue
# 1076                 Color: Night BlackPattern: Speaker         Night Black
# 1077          Color: Ultraviolet PurplePattern: Speaker  Ultraviolet Purple
# 1078                 Color: Night BlackPattern: Speaker         Night Black
# 1079                 Color: Night BlackPattern: Speaker         Night Black
#
# [1080 rows x 2 columns]

# %%
df_filled.color.unique()
# Out:
# array(['Statement Red', 'Champagne Gold', 'Matte Black', 'Black',
#        'Steel Grey', 'Red', 'Real Tree Camo', 'Navy', 'Grey Mist',
#        'Black Anthracite', 'Green', 'Chestnut', 'Stone Blue',
#        'White Smoke', 'Cypress Green', 'Chilled Lilac', 'Gray', 'Gold',
#        'Squad', 'Blue', 'Teal', 'Black & Brass', 'Cream', 'Taupe',
#        'Light Gray', 'Night Black', 'Lagoon Blue', 'Sunset Red',
#        'Ultraviolet Purple'], dtype=object)

# %%
df_filled.color.value_counts()
# Out:
# color
# Black                 433
# Black & Brass          64
# Steel Grey             55
# Night Black            54
# Gray                   50
# Black Anthracite       46
# Matte Black            44
# Blue                   40
# Red                    38
# Gold                   32
# Lagoon Blue            29
# Grey Mist              26
# Champagne Gold         26
# Light Gray             25
# Cream                  21
# Navy                   15
# Statement Red          15
# Teal                   12
# Squad                  11
# Sunset Red             10
# Green                   8
# Ultraviolet Purple      7
# Taupe                   5
# Chestnut                5
# Stone Blue              3
# Real Tree Camo          2
# White Smoke             2
# Cypress Green           1
# Chilled Lilac           1
# Name: count, dtype: int64

# %%
df_filled.head()
# Out:
#         review_id  product_id  rating  \
# 0  R2SSSH04J4J264  B0D4SX9RC6       5
# 1   R935PCZ92UVGL  B0D4SX9RC6       5
# 2   R4BQHA0TLLJNN  B0D4SX9RC6       5
# 3  R39X7USU3OX34C  B0D4SX9RC6       5
# 4  R2EVRTXO9M1YF7  B0D4SX9RC6       4
#
#                                              content  \
# 0  Needed a new portable speaker for the home set...
# 1  We bought this for a trip to the beach and it ...
# 2  I really like the new Beats Pill 2024 speaker....
# 3  So I’m super picky about sound and have spent ...
# 4  I bought this because it was on sale, and I al...
#
#                                          timestamp  \
# 0       Reviewed in the United States July 1, 2024
# 1  Reviewed in the United States September 5, 2024
# 2      Reviewed in the United States July 11, 2024
# 3       Reviewed in the United States July 8, 2024
# 4      Reviewed in the United States July 23, 2024
#
#                      profile_id  is_verified  helpful_count  \
# 0  AFVM53KRAU5JC462ZZDBBKTESPGA         True             18
# 1  AFPN35SDBWBDQAGNSNQJQPQH5C2Q         True              0
# 2  AEUCX7EIPTMCFN4OJBZHL2OYSVKQ         True              8
# 3  AFSZPNTTLYCLNP536L6VS6UMFTNQ         True              7
# 4  AHAMVBSECCNUJMQV6A3BO3A3HNMA         True              5
#
#                                   product_attributes  product_brand_name  \
# 0  Color: Statement RedStyle: PillPattern: Withou...  Beats Pill Speaker
# 1  Color: Champagne GoldStyle: PillPattern: Witho...  Beats Pill Speaker
# 2  Color: Champagne GoldStyle: PillPattern: Witho...  Beats Pill Speaker
# 3  Color: Statement RedStyle: PillPattern: Withou...  Beats Pill Speaker
# 4  Color: Matte BlackStyle: PillPattern: Without ...  Beats Pill Speaker
#
#    product_price($)                                             titles  \
# 0            149.95  Really nice portable speaker for the price. So...
# 1            149.95                                         Very Happy
# 2            149.95    The best Speaker I have ever bought in my life!
# 3            149.95                                        Really good
# 4            149.95                              Is it the JBL killer?
#
#    verified_binary date_extracted           color
# 0                1     2024-07-01   Statement Red
# 1                1     2024-09-05  Champagne Gold
# 2                1     2024-07-11  Champagne Gold
# 3                1     2024-07-08   Statement Red
# 4                1     2024-07-23     Matte Black

# %% [markdown]
# 7. Converting DataFrame into an exportable CSV file

# %%
# output to csv
df_filled.to_csv('../Datasets/final_cleaned_reviews.csv')

# %%
# output to csv
df_filled.to_csv('../3.Sentiment_Analysis_with_Advanced_EDA(Stage_3)/final_cleaned_reviews.csv')

# %%
# output to csv
df_filled.to_csv('final_cleaned_reviews.csv')
